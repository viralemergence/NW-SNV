# %%
import pandas as pd
# Out:
# /Users/ricardorivero/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
sequencing_metrics = pd.read_csv('../combined_mapping_report.csv')

for column in sequencing_metrics.columns:
    min_val = sequencing_metrics[column].min()
    max_val = sequencing_metrics[column].max()
    print(f'{column}: min={min_val}, max={max_val}')
# Out:
# sample: min=2DZNTT_1_1_SNVT_MIPE_222, max=YMD9RR_9_SNVT_PEMA_WHIT12
# mapped_reads: min=147, max=5373
# percentage_mapped: min=1.53, max=53.45
# segment: min=NM11_LRef, max=NM11_SRef
# percent_non_N: min=23.63, max=100.0
# mean_depth: min=6.8, max=476.1
